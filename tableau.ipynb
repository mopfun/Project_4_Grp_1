# %%
# Import our dependencies
import pandas as pd
from pathlib import Path
import pandas as pd

# %%
path = Path("Resources/tableau.csv")
tableau = pd.read_csv(path)
tableau
# Out:
#       row_id                       movie_name  rating      votes  meta_score  \
# 0          0           Leave the World Behind     6.5    90000.0        67.0
# 1         27  Chicken Run: Dawn of the Nugget     6.5     6300.0        63.0
# 2         23                              Leo     7.0    21000.0        65.0
# 3         16                    Family Switch     5.6    16000.0        37.0
# 4         30      The Super Mario Bros. Movie     7.0   213000.0        46.0
# ...      ...                              ...     ...        ...         ...
# 2092     937                               Up     8.3  1100000.0        88.0
# 2093     416                        Good Boys     6.7    80000.0         NaN
# 2094    1803                      Naked Lunch     6.9    56000.0        67.0
# 2095    1681           The Tragedy of Macbeth     7.1    38000.0        87.0
# 2096     970                          Warrior     8.1   491000.0        71.0
#
# ...

# %% [markdown]
# ### Checking for nulls

# %%
clean__df = tableau.dropna()
clean__df
# Out:
#      row_id                       movie_name  rating     votes  meta_score  \
# 0         0           Leave the World Behind     6.5   90000.0        67.0
# 1        27  Chicken Run: Dawn of the Nugget     6.5    6300.0        63.0
# 2        23                              Leo     7.0   21000.0        65.0
# 4        30      The Super Mario Bros. Movie     7.0  213000.0        46.0
# 5        92                       Underwater     5.9   93000.0        48.0
# ..      ...                              ...     ...       ...         ...
# 127    1927               The Lincoln Lawyer     7.3  251000.0        63.0
# 129     738                           Nimona     7.6   36000.0        75.0
# 131     300                          Get Out     7.8  674000.0        85.0
# 134    1497                          Shooter     7.1  351000.0        53.0
# 135     286                        Prisoners     8.1  785000.0        70.0
#
# ...

# %%
#save the cleaned version
clean__df.to_csv('cleaned_tableau.csv', index=False)
