# %%
# Import our dependencies
import pandas as pd
from pathlib import Path
import pandas as pd

# %%
path = Path("Resources/tableau.csv")
tableau = pd.read_csv(path)
tableau
# Out:
#       row_id                       movie_name  rating      votes  meta_score  \
# 0       1562           Leave the World Behind     7.7     2300.0         NaN
# 1          0           Leave the World Behind     6.5    90000.0        67.0
# 2         27  Chicken Run: Dawn of the Nugget     6.5     6300.0        63.0
# 3         23                              Leo     7.0    21000.0        65.0
# 4         16                    Family Switch     5.6    16000.0        37.0
# ...      ...                              ...     ...        ...         ...
# 2132     937                               Up     8.3  1100000.0        88.0
# 2133     416                        Good Boys     6.7    80000.0         NaN
# 2134    1803                      Naked Lunch     6.9    56000.0        67.0
# 2135    1681           The Tragedy of Macbeth     7.1    38000.0        87.0
# 2136     970                          Warrior     8.1   491000.0        71.0
#
#                             genre0     genre1      genre2     genre3  \
# 0                              NaN        NaN         NaN        NaN
# 1         Drama, Mystery, Thriller      Drama     Mystery   Thriller
# 2     Animation, Adventure, Comedy  Animation   Adventure     Comedy
# 3        Animation, Comedy, Family  Animation      Comedy     Family
# 4                   Comedy, Family     Comedy      Family        NaN
# ...                            ...        ...         ...        ...
# 2132  Animation, Adventure, Comedy  Animation   Adventure     Comedy
# 2133                           NaN        NaN         NaN        NaN
# 2134                         Drama      Drama         NaN        NaN
# 2135      Drama, Mystery, Thriller      Drama     Mystery   Thriller
# 2136          Action, Drama, Sport     Action       Drama      Sport
#
#      pr_rating  ...              cast1               cast2  \
# 0      Unrated  ...                NaN                 NaN
# 1            R  ...      Julia Roberts      Mahershala Ali
# 2           PG  ...    Thandiwe Newton        Zachary Levi
# 3           PG  ...       Adam Sandler           Bill Burr
# 4           PG  ...    Jennifer Garner            Ed Helms
# ...        ...  ...                ...                 ...
# 2132        PG  ...       Edward Asner        Jordan Nagai
# 2133         R  ...                NaN                 NaN
# 2134         R  ...       Peter Weller          Judy Davis
# 2135         R  ...  Denzel Washington   Frances McDormand
# 2136     PG-13  ...          Tom Hardy          Nick Nolte
#
#                    cast3                 cast4  \
# 0                    NaN                   NaN
# 1            Ethan Hawke               Myha'la
# 2           Bella Ramsey       Imelda Staunton
# 3          Cecily Strong       Jason Alexander
# 4             Emma Myers            Brady Noon
# ...                  ...                   ...
# 2132   John Ratzenberger   Christopher Plummer
# 2133                 NaN                   NaN
# 2134            Ian Holm          Julian Sands
# 2135        Alex Hassell         Bertie Carvel
# 2136       Joel Edgerton     Jennifer Morrison
#
#                                              director number_rating  \
# 0                                                 NaN           6.0
# 1                                          Sam Esmail           4.0
# 2                                            Sam Fell           2.0
# 3     Robert MarianettiRobert SmigelDavid Wachtenheim           2.0
# 4                                                 McG           2.0
# ...                                               ...           ...
# 2132                          Pete DocterBob Peterson           2.0
# 2133                                              NaN           4.0
# 2134                                 David Cronenberg           4.0
# 2135                                        Joel Coen           4.0
# 2136                                   Gavin O'Connor           3.0
#
#      weekly_rank weekly_hours_viewed  weekly_views  cumulative_weeks_in_top_10
# 0            1.0         106200000.0    44900000.0                         2.0
# 1            1.0         106200000.0    44900000.0                         2.0
# 2            2.0          20300000.0    11900000.0                         1.0
# 3            3.0          16800000.0     9400000.0                         4.0
# 4            4.0          16600000.0     9400000.0                         3.0
# ...          ...                 ...           ...                         ...
# 2132         NaN                 NaN           NaN                         NaN
# 2133         NaN                 NaN           NaN                         NaN
# 2134         NaN                 NaN           NaN                         NaN
# 2135         NaN                 NaN           NaN                         NaN
# 2136         NaN                 NaN           NaN                         NaN
#
# [2137 rows x 23 columns]
