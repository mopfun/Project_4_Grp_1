# %%
# Import our dependencies
import pandas as pd
from pathlib import Path

# %%
path = Path("Resources/final_data.csv")
df = pd.read_csv(path)
df.head()
# Out:
#    row_id                       movie_name  rating     votes  meta_score  \
# 0       0           Leave the World Behind     6.5   90000.0          67
# 1      16                    Family Switch     5.6   16000.0          37
# 2      19   How the Grinch Stole Christmas     6.3  280000.0          46
# 3      23                              Leo     7.0   21000.0          65
# 4      27  Chicken Run: Dawn of the Nugget     6.5    6300.0          63
#
#                          genre0     genre1      genre2     genre3 pr_rating  \
# 0      Drama, Mystery, Thriller      Drama     Mystery   Thriller         R
# 1                Comedy, Family     Comedy      Family        NaN        PG
# 2       Comedy, Family, Fantasy     Comedy      Family    Fantasy        PG
# 3     Animation, Comedy, Family  Animation      Comedy     Family        PG
# 4  Animation, Adventure, Comedy  Animation   Adventure     Comedy        PG
#
#    ...                                              cast0            cast1  \
# 0  ...  Julia Roberts, Mahershala Ali, Ethan Hawke, My...    Julia Roberts
# 1  ...  Jennifer Garner, Ed Helms, Emma Myers, Brady Noon  Jennifer Garner
# 2  ...  Jim Carrey, Taylor Momsen, Kelley, Jeffrey Tambor       Jim Carrey
# 3  ...  Adam Sandler, Bill Burr, Cecily Strong, Jason ...     Adam Sandler
# 4  ...  Thandiwe Newton, Zachary Levi, Bella Ramsey, I...  Thandiwe Newton
#
#              cast2           cast3             cast4  \
# 0   Mahershala Ali     Ethan Hawke           Myha'la
# 1         Ed Helms      Emma Myers        Brady Noon
# 2    Taylor Momsen          Kelley    Jeffrey Tambor
# 3        Bill Burr   Cecily Strong   Jason Alexander
# 4     Zachary Levi    Bella Ramsey   Imelda Staunton
#
#                                           director number_rating  \
# 0                                       Sam Esmail             4
# 1                                              McG             2
# 2                                       Ron Howard             2
# 3  Robert MarianettiRobert SmigelDavid Wachtenheim             2
# 4                                         Sam Fell             2
#
#   netflix_top_10  weekly_hours_viewed  weekly_views
# 0              1           98700000.0    41700000.0
# 1              1           39200000.0    22200000.0
# 2              1            7530000.0           NaN
# 3              1           61700000.0    34600000.0
# 4              1           20300000.0    11900000.0
#
# [5 rows x 22 columns]

# %%
# df['cast0']

# %%
cast_df = df[['cast1', 'cast2', 'cast3', 'cast4']]
cast_df
# Out:
#                 cast1                  cast2             cast3  \
# 0       Julia Roberts         Mahershala Ali       Ethan Hawke
# 1     Jennifer Garner               Ed Helms        Emma Myers
# 2          Jim Carrey          Taylor Momsen            Kelley
# 3        Adam Sandler              Bill Burr     Cecily Strong
# 4     Thandiwe Newton           Zachary Levi      Bella Ramsey
# ...               ...                    ...               ...
# 1729    Mark Wahlberg   Nicola Peltz Beckham       Jack Reynor
# 1730      Adam Driver       Marion Cotillard     Simon Helberg
# 1731    Ryan Reynolds           Rachel Weisz   Abigail Breslin
# 1732    Jeff Goldblum            Geena Davis         John Getz
# 1733   Emilio Estevez           Joss Ackland        Lane Smith
#
#                  cast4
# 0              Myha'la
# 1           Brady Noon
# 2       Jeffrey Tambor
# 3      Jason Alexander
# 4      Imelda Staunton
# ...                ...
# 1729     Stanley Tucci
# 1730    Devyn McDowell
# 1731         An Nguyen
# 1732       Joy Boushel
# 1733       Heidi Kling
#
# [1734 rows x 4 columns]

# %%
# Count duplicates per row across columns
cast_df['duplicate_count'] = cast_df.apply(lambda row: len(row) - len(set(row)), axis=1)
# print(cast_df)
cast_df.head()
# Out:
# /var/folders/hc/nkkc_9yd3fd9x9025zg61t2w0000gn/T/ipykernel_41861/1732773915.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cast_df['duplicate_count'] = cast_df.apply(lambda row: len(row) - len(set(row)), axis=1)
#              cast1            cast2           cast3             cast4  \
# 0    Julia Roberts   Mahershala Ali     Ethan Hawke           Myha'la
# 1  Jennifer Garner         Ed Helms      Emma Myers        Brady Noon
# 2       Jim Carrey    Taylor Momsen          Kelley    Jeffrey Tambor
# 3     Adam Sandler        Bill Burr   Cecily Strong   Jason Alexander
# 4  Thandiwe Newton     Zachary Levi    Bella Ramsey   Imelda Staunton
#
#    duplicate_count
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
#alt option to see if there are any duplicates by 'flagging' it with a true or false stmt
cast_df['has_duplicate'] = cast_df.apply(lambda row: len(set(row)) < len(row), axis=1)
# print(df)
cast_df.head()
# Out:
# /var/folders/hc/nkkc_9yd3fd9x9025zg61t2w0000gn/T/ipykernel_41861/3888320501.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cast_df['has_duplicate'] = cast_df.apply(lambda row: len(set(row)) < len(row), axis=1)
#              cast1            cast2           cast3             cast4  \
# 0    Julia Roberts   Mahershala Ali     Ethan Hawke           Myha'la
# 1  Jennifer Garner         Ed Helms      Emma Myers        Brady Noon
# 2       Jim Carrey    Taylor Momsen          Kelley    Jeffrey Tambor
# 3     Adam Sandler        Bill Burr   Cecily Strong   Jason Alexander
# 4  Thandiwe Newton     Zachary Levi    Bella Ramsey   Imelda Staunton
#
#    duplicate_count  has_duplicate
# 0                0          False
# 1                0          False
# 2                0          False
# 3                0          False
# 4                0          False

# %%
#showing the dup counts in cast1 row
cast1_counts = cast_df['cast1'].value_counts()
# cast1_counts
cast2_counts = cast_df['cast2'].value_counts()
# cast2_counts
cast3_counts = cast_df['cast3'].value_counts()
# cast3_counts
cast4_counts = cast_df['cast4'].value_counts()
# cast4_counts

print(cast1_counts)
print(cast2_counts)
print(cast3_counts)
print(cast4_counts)
# Out:
# cast1
# Tom Cruise           26
# Tom Hanks            23
# Leonardo DiCaprio    18
# Adam Sandler         17
# Brad Pitt            16
#                      ..
# Chyler Leigh          1
# Amy Poehler           1
# Alec Baldwin          1
# Carrie Coon           1
# Alison Lohman         1
# Name: count, Length: 762, dtype: int64
# cast2
#  Samuel L. Jackson    9
#  Rachel McAdams       8
#  Emma Watson          8
#  Matt Damon           8
#  Brad Pitt            7
#                      ..
#  Zac Efron            1
#  Aubrey Plaza         1
#  R. Lee Ermey         1
#  Lewis McAskie        1
#  Joss Ackland         1
# Name: count, Length: 1095, dtype: int64
# cast3
#  Willem Dafoe          10
#  Scarlett Johansson     8
#  Samuel L. Jackson      8
#  Mark Ruffalo           7
#  Jennifer Connelly      6
#                        ..
#  Ophelia Lovibond       1
#  Maria Pitillo          1
#  Chief Dan George       1
#  Tobey Maguire          1
#  Lane Smith             1
# Name: count, Length: 1274, dtype: int64
# cast4
#  Cate Blanchett           6
#  Abigail Breslin          5
#  Famke Janssen            5
#  Cliff Curtis             4
#  Willem Dafoe             4
#                          ..
#  Priyanka Chopra Jonas    1
#  Michael McElhatton       1
#  Jemma Redgrave           1
#  Natasha Liu Bordizzo     1
#  Heidi Kling              1
# Name: count, Length: 1414, dtype: int64

# %% [markdown]
# ### Creating a pd DF for each cast count

# %%
#cast1
cast1 = pd.DataFrame(cast1_counts)
cast1.head()
# Out:
#                    count
# cast1
# Tom Cruise            26
# Tom Hanks             23
# Leonardo DiCaprio     18
# Adam Sandler          17
# Brad Pitt             16

# %%
#cast2
cast2 = pd.DataFrame(cast2_counts)
cast2.head()
# Out:
#                     count
# cast2
#  Samuel L. Jackson      9
#  Rachel McAdams         8
#  Emma Watson            8
#  Matt Damon             8
#  Brad Pitt              7

# %%
#cast3
cast3 = pd.DataFrame(cast3_counts)
cast3.head()
# Out:
#                      count
# cast3
#  Willem Dafoe           10
#  Scarlett Johansson      8
#  Samuel L. Jackson       8
#  Mark Ruffalo            7
#  Jennifer Connelly       6

# %%
#cast4
cast4 = pd.DataFrame(cast4_counts)
cast4.head()
# Out:
#                   count
# cast4
#  Cate Blanchett       6
#  Abigail Breslin      5
#  Famke Janssen        5
#  Cliff Curtis         4
#  Willem Dafoe         4

# %% [markdown]
# ### Cast and top 10 DF

# %%
top_10_cast = df[['cast1', 'cast2', 'cast3', 'cast4', 'cumulative_weeks_in_top_10']]
top_10_cast.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 top_10_cast = df[['cast1', 'cast2', 'cast3', 'cast4', 'cumulative_weeks_in_top_10']]
#       2 top_10_cast.head()
#
# File /opt/anaconda3/envs/PythonData_2024_12/lib/python3.10/site-packages/pandas/core/frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/envs/PythonData_2024_12/lib/python3.10/site-packages/pandas/core/indexes/base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
#    6117 keyarr = self.take(indexer)
#    6118 if isinstance(key, Index):
#    6119     # GH 42790 - Preserve name from an Index
#
# File /opt/anaconda3/envs/PythonData_2024_12/lib/python3.10/site-packages/pandas/core/indexes/base.py:6179, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6176     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6178 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6179 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['cumulative_weeks_in_top_10'] not in index"
