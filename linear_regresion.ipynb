# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

# Import pandas and read the charity_data.csv from the provided cloud URL.
import pandas as pd
from pathlib import Path
path = Path("Resources/final_combined_data.csv")
df = pd.read_csv(path)
df.head()
# Out:
#    row_id      movie_name  rating     votes  meta_score  \
# 0     506            1917     8.2  654000.0          78
# 1    1356  21 Jump Street     7.2  589000.0          69
# 2    1698   6 Underground     6.1  192000.0          41
# 3    1698   6 Underground     6.1  192000.0          41
# 4    1698   6 Underground     6.1  192000.0          41
#
#                   genre0  genre1     genre2  genre3 pr_rating  ...  \
# 0     Action, Drama, War  Action      Drama     War         R  ...
# 1  Action, Comedy, Crime  Action     Comedy   Crime         R  ...
# 2       Action, Thriller  Action   Thriller     NaN         R  ...
# 3       Action, Thriller  Action   Thriller     NaN         R  ...
# 4       Action, Thriller  Action   Thriller     NaN         R  ...
#
#                   cast1             cast2                 cast3         cast4  \
# 0  Dean-Charles Chapman     George MacKay           Daniel Mays   Colin Firth
# 1            Jonah Hill    Channing Tatum              Ice Cube   Brie Larson
# 2         Ryan Reynolds   Mélanie Laurent   Manuel Garcia-Rulfo     Ben Hardy
# 3         Ryan Reynolds   Mélanie Laurent   Manuel Garcia-Rulfo     Ben Hardy
# 4         Ryan Reynolds   Mélanie Laurent   Manuel Garcia-Rulfo     Ben Hardy
#
#                       director number_rating weekly_rank weekly_hours_viewed  \
# 0                   Sam Mendes             4           7            10840000
# 1  Phil LordChristopher Miller             4           6            11690000
# 2                  Michael Bay             4           5             8730000
# 3                  Michael Bay             4           7             7440000
# 4                  Michael Bay             4           9             7770000
#
#    weekly_views  cumulative_weeks_in_top_10
# 0           NaN                           1
# 1           NaN                           1
# 2           NaN                           3
# 3           NaN                           2
# 4           NaN                           1
#
# [5 rows x 23 columns]

# %%
filtered_df = df[['row_id', 'rating', 'votes', 'meta_score', 'number_rating', 'weekly_rank', 'weekly_hours_viewed', 'cumulative_weeks_in_top_10' ]]
filtered_df.head()
# Out:
#    row_id  rating     votes  meta_score  number_rating  weekly_rank  \
# 0     506     8.2  654000.0          78              4            7
# 1    1356     7.2  589000.0          69              4            6
# 2    1698     6.1  192000.0          41              4            5
# 3    1698     6.1  192000.0          41              4            7
# 4    1698     6.1  192000.0          41              4            9
#
#    weekly_hours_viewed  cumulative_weeks_in_top_10
# 0             10840000                           1
# 1             11690000                           1
# 2              8730000                           3
# 3              7440000                           2
# 4              7770000                           1

# %%
# Determine the number of unique values in each column.
filtered_df.nunique()
# Out:
# row_id                        182
# rating                         36
# votes                         155
# meta_score                     63
# number_rating                   5
# weekly_rank                    10
# weekly_hours_viewed           387
# cumulative_weeks_in_top_10     14
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
filtered_df['weekly_hours_viewed'].value_counts()
# Out:
# weekly_hours_viewed
# 5400000     6
# 6500000     5
# 5900000     4
# 7300000     4
# 12290000    3
#            ..
# 4960000     1
# 65920000    1
# 69540000    1
# 24700000    1
# 55650000    1
# Name: count, Length: 387, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `top_10_replace`
wkly_hours_viewed = filtered_df['weekly_hours_viewed'].value_counts()

cutoff = 500
wkly_hours_replace = wkly_hours_viewed[wkly_hours_viewed < cutoff].index.tolist()

# Replace in dataframe
for app in wkly_hours_replace:
    filtered_df['weekly_hours_viewed'] = filtered_df['weekly_hours_viewed'].replace(app,"Other")

# Check to make sure replacement was successful
filtered_df['weekly_hours_viewed'].value_counts()
# Out:
# /var/folders/hc/nkkc_9yd3fd9x9025zg61t2w0000gn/T/ipykernel_40282/1374654805.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['weekly_hours_viewed'] = filtered_df['weekly_hours_viewed'].replace(app,"Other")
# weekly_hours_viewed
# Other    483
# Name: count, dtype: int64

# %%
# Look at weekly_rank value counts to identify and replace with "Other"
filtered_df['weekly_rank'].value_counts()
# Out:
# weekly_rank
# 9     60
# 1     54
# 7     53
# 10    51
# 6     50
# 5     49
# 3     47
# 4     42
# 8     41
# 2     36
# Name: count, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
wky_counts = filtered_df['weekly_rank'].value_counts()

#creating the code for the value count >1
wky_counts[wky_counts > 1]
# Out:
# weekly_rank
# 9     60
# 1     54
# 7     53
# 10    51
# 6     50
# 5     49
# 3     47
# 4     42
# 8     41
# 2     36
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `weekly_rank_replace`
wky_counts = filtered_df['weekly_rank'].value_counts()

cutoff = 500
weekly_rank_replace = wky_counts[wky_counts < cutoff].index.tolist()

# Replace in dataframe
for cls in weekly_rank_replace:
    filtered_df['weekly_rank'] = filtered_df['weekly_rank'].replace(cls,"Other")

# Check to make sure replacement was successful
filtered_df['weekly_rank'].value_counts()
# Out:
# /var/folders/hc/nkkc_9yd3fd9x9025zg61t2w0000gn/T/ipykernel_40282/1022141982.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['weekly_rank'] = filtered_df['weekly_rank'].replace(cls,"Other")
# weekly_rank
# Other    483
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
converted_df = pd.get_dummies(filtered_df)
converted_df.head()
# Out:
#    row_id  rating     votes  meta_score  number_rating  \
# 0     506     8.2  654000.0          78              4
# 1    1356     7.2  589000.0          69              4
# 2    1698     6.1  192000.0          41              4
# 3    1698     6.1  192000.0          41              4
# 4    1698     6.1  192000.0          41              4
#
#    cumulative_weeks_in_top_10  weekly_rank_Other  weekly_hours_viewed_Other
# 0                           1               True                       True
# 1                           1               True                       True
# 2                           3               True                       True
# 3                           2               True                       True
# 4                           1               True                       True

# %%
# Split our preprocessed data into our features and target arrays
X = converted_df.drop("cumulative_weeks_in_top_10", axis=1)
y = converted_df["cumulative_weeks_in_top_10"]

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

model = tf.keras.models.Sequential()

# First hidden layer
model.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=7))

# Second hidden layer
model.add(tf.keras.layers.Dense(units=50, activation="relu"))

# Third hidden layer
# model.add(tf.keras.layers.Dense(units=70, activation="relu"))

# Output layer
model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
model.summary()
# Out:
# /opt/anaconda3/envs/PythonData_2024_12/lib/python3.10/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 80)             │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 50)             │         4,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,741 (18.52 KB)
#  Trainable params: 4,741 (18.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2585 - loss: 0.3919
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3486 - loss: -1.1678
# Epoch 3/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3543 - loss: -2.8586
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3813 - loss: -5.0441
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3741 - loss: -8.1648
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3211 - loss: -13.5308
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3762 - loss: -18.0277
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3690 - loss: -24.6649
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3671 - loss: -35.0501
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3613 - loss: -48.6791
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3763 - loss: -56.8678
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3729 - loss: -88.4687
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3719 - loss: -96.4606
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3725 - loss: -129.4652
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3840 - loss: -155.2607
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.4040 - loss: -195.6058
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3455 - loss: -248.8828
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3795 - loss: -312.0613
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3481 - loss: -386.3672
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3522 - loss: -445.8379
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3923 - loss: -486.2234
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3582 - loss: -592.3152
# Epoch 23/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3744 - loss: -664.8279
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3525 - loss: -847.0209
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3489 - loss: -854.0959
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3679 - loss: -973.5613
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3427 - loss: -1207.8051
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3392 - loss: -1422.8973
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3320 - loss: -1573.0997
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3474 - loss: -1760.4312
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3500 - loss: -1925.0914
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3481 - loss: -2013.1802
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3599 - loss: -2346.6482
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3718 - loss: -2615.7002
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3451 - loss: -2748.8667
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3348 - loss: -3061.9897
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3679 - loss: -3078.4636
# Epoch 38/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3514 - loss: -3533.4609
# Epoch 39/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3921 - loss: -3565.5447
# Epoch 40/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3922 - loss: -3461.7458
# Epoch 41/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3551 - loss: -4290.9604
# Epoch 42/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3769 - loss: -4722.4688
# Epoch 43/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3781 - loss: -5294.5488
# Epoch 44/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3434 - loss: -6294.0620
# Epoch 45/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3265 - loss: -6174.3584
# Epoch 46/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3720 - loss: -6265.4834
# Epoch 47/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3698 - loss: -5894.7188
# Epoch 48/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3456 - loss: -6879.6133
# Epoch 49/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3622 - loss: -7505.5396
# Epoch 50/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3518 - loss: -7879.4937
# Epoch 51/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3659 - loss: -9264.3906
# Epoch 52/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3493 - loss: -9320.4238
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3787 - loss: -9929.9658
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3828 - loss: -9605.1182
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3193 - loss: -10829.5938
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3685 - loss: -10804.9170
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3577 - loss: -12330.8555
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3538 - loss: -12381.9150
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3456 - loss: -14162.9355
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3710 - loss: -13712.2031
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3703 - loss: -15768.1377
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3540 - loss: -14166.2607
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3450 - loss: -16299.9727
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3502 - loss: -16560.6973
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3474 - loss: -19163.9922
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3641 - loss: -18539.3672
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3995 - loss: -19300.2539
# Epoch 68/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3510 - loss: -21173.6387
# Epoch 69/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3945 - loss: -19346.6230
# Epoch 70/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3529 - loss: -23730.9551
# Epoch 71/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3680 - loss: -22983.0078
# Epoch 72/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3521 - loss: -24711.4102
# Epoch 73/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3561 - loss: -24226.5664
# Epoch 74/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3331 - loss: -27486.9121
# Epoch 75/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3695 - loss: -25982.5859
# Epoch 76/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3873 - loss: -25187.4238
# Epoch 77/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3278 - loss: -29645.0332
# Epoch 78/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3771 - loss: -30630.3223
# Epoch 79/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3454 - loss: -32171.3164
# Epoch 80/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3462 - loss: -32805.7109
# Epoch 81/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3384 - loss: -34546.7109
# Epoch 82/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3727 - loss: -35254.1641
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3878 - loss: -33506.5977
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3763 - loss: -40058.0273
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3732 - loss: -39244.6289
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3422 - loss: -42378.1680
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3578 - loss: -46236.9453
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3639 - loss: -39995.9141
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3401 - loss: -44756.1289
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3848 - loss: -44975.9375
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3594 - loss: -45002.1367
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3545 - loss: -50520.5703
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3588 - loss: -51242.1836
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3375 - loss: -49180.0703
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3652 - loss: -55548.3711
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3852 - loss: -54540.4844
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3936 - loss: -55707.2852
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3654 - loss: -57841.8320
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3776 - loss: -60124.4531
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3443 - loss: -60452.5547

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 4/4 - 0s - 17ms/step - accuracy: 0.4298 - loss: -5.5183e+04
# Loss: -55183.25390625, Accuracy: 0.42975205183029175
