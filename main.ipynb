# %%
# Import our dependencies
import pandas as pd
from pathlib import Path
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
import pandas as pd
# import tensorflow as tf

# %%
pop = Path("Resources/most-popular.csv")
pop_df = pd.read_csv(pop)
pop_df.head()
# Out:
#           category  rank        show_title season_title  \
# 0  Films (English)     1        Red Notice          NaN
# 1  Films (English)     2     Don't Look Up          NaN
# 2  Films (English)     3  The Adam Project          NaN
# 3  Films (English)     4          Bird Box          NaN
# 4  Films (English)     5      The Gray Man          NaN
#
#    hours_viewed_first_91_days  runtime  views_first_91_days
# 0                   454200000   1.9667            230900000
# 1                   408600000   2.3833            171400000
# 2                   281000000   1.7833            157600000
# 3                   325300000   2.0667            157400000
# 4                   299500000   2.1500            139300000

# %%
filt_pop = pop_df[pop_df['category'] == 'TV (English)']
filt_pop.head()
# Out:
#         category  rank          show_title  \
# 20  TV (English)     1           Wednesday
# 21  TV (English)     2     Stranger Things
# 22  TV (English)     3              DAHMER
# 23  TV (English)     4          Bridgerton
# 24  TV (English)     5  The Queen's Gambit
#
#                                  season_title  hours_viewed_first_91_days  \
# 20                        Wednesday: Season 1                  1718800000
# 21                          Stranger Things 4                  1838000000
# 22  DAHMER: Monster: The Jeffrey Dahmer Story                  1031100000
# 23                       Bridgerton: Season 1                   929300000
# 24         The Queen's Gambit: Limited Series                   746400000
#
#     runtime  views_first_91_days
# 20   6.8167            252100000
# 21  13.0667            140700000
# 22   8.9167            115600000
# 23   8.2000            113300000
# 24   6.6167            112800000

# %%
# country = Path("Resources/all-weeks-countries.csv")
# country_df = pd.read_csv(country, encoding='latin1')
# country_df.head()

# %%
# filt_country = country_df[country_df['category'] == 'TV (English)']
# filt_country

# %%
wks_global = Path("Resources/all-weeks-global.csv")
wks_global_df = pd.read_csv(wks_global, encoding='latin1')
wks_global_df.head()
# Out:
#          week         category  weekly_rank                       show_title  \
# 0  2023-12-17  Films (English)            1           Leave the World Behind
# 1  2023-12-17  Films (English)            2  Chicken Run: Dawn of the Nugget
# 2  2023-12-17  Films (English)            3                              Leo
# 3  2023-12-17  Films (English)            4                    Family Switch
# 4  2023-12-17  Films (English)            5      The Super Mario Bros. Movie
#
#   season_title  weekly_hours_viewed  runtime  weekly_views  \
# 0          NaN            106200000   2.3667    44900000.0
# 1          NaN             20300000   1.7000    11900000.0
# 2          NaN             16800000   1.7833     9400000.0
# 3          NaN             16600000   1.7667     9400000.0
# 4          NaN             13700000   1.5333     8900000.0
#
#    cumulative_weeks_in_top_10  is_staggered_launch episode_launch_details
# ...

# %%
# filt_global = wks_global_df[wks_global_df['category'] == 'TV (English)']
filt_global = wks_global_df[wks_global_df['category'] == 'Films (English)']
# filt_global = wks_global_df.drop(['season_title', 'is_staggered_launch', 'episode_launch_details'])
filt_global
# Out:
#             week         category  weekly_rank  \
# 0     2023-12-17  Films (English)            1
# 1     2023-12-17  Films (English)            2
# 2     2023-12-17  Films (English)            3
# 3     2023-12-17  Films (English)            4
# 4     2023-12-17  Films (English)            5
# ...          ...              ...          ...
# 5125  2021-07-04  Films (English)            6
# 5126  2021-07-04  Films (English)            7
# 5127  2021-07-04  Films (English)            8
# 5128  2021-07-04  Films (English)            9
# 5129  2021-07-04  Films (English)           10
#
#                            show_title season_title  weekly_hours_viewed  \
# 0              Leave the World Behind          NaN            106200000
# 1     Chicken Run: Dawn of the Nugget          NaN             20300000
# 2                                 Leo          NaN             16800000
# 3                       Family Switch          NaN             16600000
# ...

# %%
#Loading the IMDb movie data CSV file
imdb = Path("Resources/imdb_movie_data_2023.csv")
imdb_df = pd.read_csv(imdb, index_col=0)
imdb_df.head()
# Out:
#                     Moive Name  Rating     Votes  Meta Score  \
# 0       Leave the World Behind     6.5   90000.0        67.0
# 1                        Wonka     7.4   24000.0        66.0
# 2                  Poor Things     8.5    6700.0        86.0
# 3   Killers of the Flower Moon     7.8  128000.0        89.0
# 4                 May December     7.0   21000.0        85.0
#
#                        Genre PG Rating  Year Duration  \
# 0   Drama, Mystery, Thriller         R  2023   2h 18m
# 1  Adventure, Comedy, Family        PG  2023   1h 56m
# 2     Comedy, Drama, Romance         R  2023   2h 21m
# 3      Crime, Drama, History         R  2023   3h 26m
# 4              Comedy, Drama         R  2023   1h 57m
#
#                                                 Cast          Director
# 0  Julia Roberts, Mahershala Ali, Ethan Hawke, My...        Sam Esmail
# 1  Timothée Chalamet, Gustave Die, Murray McArthu...         Paul King
# ...

# %%
#final csv file
final = Path("Resources/final_combined_data.csv")
final_df = pd.read_csv(final, index_col=0)
final_df.head()
# Out:
#             movie_name  rating     votes  meta_score                 genre0  \
# row_id
# 506               1917     8.2  654000.0          78     Action, Drama, War
# 1356    21 Jump Street     7.2  589000.0          69  Action, Comedy, Crime
# 1698     6 Underground     6.1  192000.0          41       Action, Thriller
# 1698     6 Underground     6.1  192000.0          41       Action, Thriller
# 1698     6 Underground     6.1  192000.0          41       Action, Thriller
#
#         genre1     genre2  genre3 pr_rating  year  ...                 cast1  \
# row_id                                             ...
# 506     Action      Drama     War         R  2019  ...  Dean-Charles Chapman
# 1356    Action     Comedy   Crime         R  2012  ...            Jonah Hill
# 1698    Action   Thriller     NaN         R  2019  ...         Ryan Reynolds
# 1698    Action   Thriller     NaN         R  2019  ...         Ryan Reynolds
# ...

# %% [markdown]
# ### Final csv file

# %%
path = Path("Resources/final_combined_data_no_rank.csv")
df = pd.read_csv(path)
df
# Out:
#       row_id                       movie_name  rating     votes  meta_score  \
# 0          0           Leave the World Behind     6.5   90000.0          67
# 1         16                    Family Switch     5.6   16000.0          37
# 2         19   How the Grinch Stole Christmas     6.3  280000.0          46
# 3         23                              Leo     7.0   21000.0          65
# 4         27  Chicken Run: Dawn of the Nugget     6.5    6300.0          63
# ...      ...                              ...     ...       ...         ...
# 1729    1943  Transformers: Age of Extinction     5.6  328000.0          32
# 1730    1944                          Annette     6.3   22000.0          67
# 1731    1945                Definitely, Maybe     7.1  172000.0          59
# 1732    1946                          The Fly     7.6  198000.0          79
# 1733    1947                 The Mighty Ducks     6.5   71000.0          46
#
# ...
